# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/jamesrobertlloyd/gp-structure-search/master/data/raw/TSDL/monthly-beer-production-in-austr.csv",sep=',')

# %%
data.info

# %%
#읽은 CVS의 데이터 형태 분석
data.shape

# %% [markdown]
# df1의 데이터는 477개의 열과 2개의 행으로 되어있다.

# %%
data1 = data["Monthly beer production in Australia: megalitres. Includes ale and stout. Does not include beverages with alcohol percentage less than 1.15. Jan 1956 ? Aug 1995"]

# %%
print(data1)

# %% [markdown]
# 총 0~476개의 데이터가 있음

# %%
plt.title('Aust. beer data')
plt.plot(data1)

# %% [markdown]
# 노이즈가 발생하는 구간은 재귀식을 활영하여 평균 그래프를 그려보자
#
# 이동 평균을 구해야 한다.

# %%
#def get_beer():
#    """Measure beer."""
#    b = np.random.normal(0, 4)  # v: measurement noise.
#   beer_mean = 13.4            # volt_mean: mean (nominal) voltage [V].
#   beer_meas = beer_mean + b   # volt_meas: measured voltage [V] (observable).
#   return beer_meas

# %%
##재귀식 만들기

def average(k, x_avg_k_1, x_measure):
  alpha = (k-1)/k
  x_avg_k = alpha * x_avg_k_1 + (1- alpha)*x_measure 

  return x_avg_k

# %%
for i in range(0,475):
    x_data = data1[i]   #x_data 에 data의 array를 보냄
    print(x_data)

# %%
x_avg_k_1 = 0
x_measure = 0

for i in range(0,475):
  k = i + 1
  x_meas_save = data1[i] 
  x_avg_save = data1[i]
  x_avg_k = average(k, x_avg_k_1, x_measure)
  x_meas = x_meas_save
  x_avg = x_avg_k
  
  print(x_data)

# %%
plt.plot(time, x_meas_save, 'r*', label='Measured')
plt.plot(time, x_avg_save, 'b-', label='Average')
plt.legend(loc='upper left')
plt.title('Measured Voltages v.s. Average Filter Values')
plt.xlabel('Time [sec]')
plt.ylabel('Volt [V]')
plt.savefig('/content/img')
